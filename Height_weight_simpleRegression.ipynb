# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/data.csv")
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.columns
# Out:
# Index(['Height', 'Weight'], dtype='object')

# %%
df.head()
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48
# 3    1.55   55.84
# 4    1.57   57.20

# %%
df.tail()
# Out:
#     Height  Weight
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-633337079cd0> in <module>
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.isna().sum()
# Out:
# Height    0
# Weight    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([57.1998501 , 66.93314565, 55.98318816, 71.19146245, 65.10815273])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred)

# %%
df1=pd.DataFrame({"Actaul_value":y_test,"predicted_value":y_pred})
df1
# Out:
#     Actaul_value  predicted_value
# 4          57.20        57.199850
# 10         66.28        66.933146
# 3          55.84        55.983188
# 13         72.19        71.191462
# 9          64.47        65.108153

# %%
from sklearn.metrics import mean_absolute_error
error=mean_absolute_error(y_test,y_pred)
error
# Out:
# 0.4866347975240529

# %%
from sklearn.metrics import mean_absolute_percentage_error
per=mean_absolute_percentage_error(y_test,y_pred)
per
# Out:
# 0.007230347772500104

# %%
from sklearn.metrics import mean_squared_error
sqa=mean_squared_error(y_test,y_pred)
sqa
# Out:
# 0.37028365148666564

# %%
from sklearn.metrics import mean_squared_error
sqr=np.sqrt(sqa)
sqr
# Out:
# 0.6085093684460952

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9898323398401543
